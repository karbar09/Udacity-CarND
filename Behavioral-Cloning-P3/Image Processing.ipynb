# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('examples/.jpg')
cv.imwrite('examples/recov_3.png',img)
#flipped = cv.flip(img,flipCode=1)
# Out:
# True

# %%
# %matplotlib inline
plt.imshow(flipped)

# %%
cv.imwrite('examples/flipped_image.png',flipped)
# Out:
# True
